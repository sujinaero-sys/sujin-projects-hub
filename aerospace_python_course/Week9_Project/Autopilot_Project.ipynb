# %% [markdown]
# # Week 9 – Capstone Project Week 🎓
#
# Focus: Students complete a project that synthesizes course topics. Provide options, milestones, and grading rubric.
#
# ---
#
# ### Project Options
# 1. **Autopilot Implementation (Simulation)**: takeoff → climb → cruise → descent → landing; waypoint following; simple fault handling.
# 2. **Flight Data Analysis Report**: use an open dataset (ADS-B or NASA flight test) to clean, analyze, and present performance metrics.
# 3. **CFD Mini-Project**: analyze 2D airfoil using potential flow & plot pressure distribution; compare simple models.

# %% [markdown]
# ## Milestones (Suggested)
#
# - **Day 1–2:** Project selection & proposal (1 page)
# - **Day 3–5:** Data collection / simulation implementation
# - **Day 6–7:** Results, report, and final presentation (10 min)

# %% [markdown]
# ## Grading Rubric (100 pts)
#
# - Design & Implementation: 40 pts
# - Analysis & Results: 30 pts
# - Code Quality & Reproducibility: 15 pts
# - Presentation & Report: 15 pts

# %%
# Project template helpers (example: autopilot project folder creation)
import os
project_name = "Autopilot_Project_Student"
os.makedirs(project_name, exist_ok=True)
with open(os.path.join(project_name, "README.md"), "w") as f:
    f.write("# Autopilot Project\n\nDescribe your project, approach, and dependencies here.")
print("Created project folder:", project_name)
# Out:
# Created project folder: Autopilot_Project_Student

# %% [markdown]
# ## Example starter code snippet (Autopilot controller loop)
#
# ```python
# # inside your project main loop
# current_pos = get_position()
# setpoint = get_next_waypoint()
# control = guidance_law(current_pos, setpoint)
# actuate(control)
# log_state()
# ```

# %% [markdown]
# ## Submission Checklist
# - Code in a GitHub repo
# - `requirements.txt` and instructions to run
# - Project report (PDF) with figures
# - Short demo video or live demo during presentation
